# %%
import numpy as np
import pandas as pd

# %%
scores_series = {"James":50,"Alfa":70,"Alfredo":90}
data =[50,70,80]
index_data=["Asim","Safar","Temraz"]

# %%
pd.Series(scores_series)
pd.Series(data=data,index=index_data)
# Out:
# Asim      50
# Safar     70
# Temraz    80
# dtype: int64

# %%
#aritchemt

# %%
ksq_1 = pd.Series({"James":50,"Alfa":70,"Alfredo":90})
ksq_2 = pd.Series({"James":30,"Alfa":50,"Alfredo":20})

# %%
ksq_1 * ksq_2
# Out:
# James      1500
# Alfa       3500
# Alfredo    1800
# dtype: int64

# %%
ksq_1 - ksq_2
# Out:
# James      20
# Alfa       20
# Alfredo    70
# dtype: int64

# %%
ksq_1 / ksq_2
# Out:
# James      1.666667
# Alfa       1.400000
# Alfredo    4.500000
# dtype: float64

# %%
ksq_1 + ksq_2
# Out:
# James       80
# Alfa       120
# Alfredo    110
# dtype: int64

# %%
df_np = np.array([50,70,90])
df_np
# Out:
# array([50, 70, 90])

# %%
df = pd.Series(df_np,index=["James","Alfredo","Temraz"])
df
# Out:
# James      50
# Alfredo    70
# Temraz     90
# dtype: int64

# %%
df.iloc[0]=99

# %%
df
# Out:
# James      99
# Alfredo    70
# Temraz     90
# dtype: int64

# %%
df["James"]
# Out:
# np.int64(99)
